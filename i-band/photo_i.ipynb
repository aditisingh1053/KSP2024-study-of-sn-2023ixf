# %%
import numpy as np
import numpy.ma as ma
import matplotlib.pyplot as plt
import astropy.units as u
from astropy.io import fits
from astropy.stats import sigma_clipped_stats, sigma_clip
from astropy.table import Table
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS
from astropy.visualization import ZScaleInterval
from astroquery.vizier import Vizier
import subprocess
import os
from IPython.display import clear_output
import glob

def test_dependency(dep, alternate_name=None):
    """
    Test external dependency by trying to run it as a subprocess
    """
    try:
        subprocess.check_output(dep, stderr=subprocess.PIPE, shell=True)
        print("%s is installed properly as %s. OK" % (dep, dep))
        return 1
    except subprocess.CalledProcessError:
        try:
            subprocess.check_output(alternate_name, stderr=subprocess.PIPE, shell=True)
            print("%s is installed properly as %s. OK" % (dep, alternate_name))
            return 1
        except subprocess.CalledProcessError:
            print("===%s/%s IS NOT YET INSTALLED PROPERLY===" % (dep, alternate_name))
            return 0
    
dependencies = [('source-extractor', 'sex'), ('psfex', 'PSFEx')]
i = 0
for dep_name1, dep_name2 in dependencies:
    i += test_dependency(dep_name1, dep_name2)
print("%i out of %i external dependencies installed properly.\n" % (i, len(dependencies)))
if i != len(dependencies):
    print("Please correctly install these programs before continuing by following the instructions in README.md.")
else:
    print("You are ready to continue.") 

directory='/home/aditi/ksp/i-band/data'
all_images=[]
pattern = os.path.join(directory, '*RA.wcs.proc.fits')
for filename in glob.glob(pattern):
    all_images.append(os.path.basename(filename))

print(len(all_images))
# Out:
# source-extractor is installed properly as source-extractor. OK
# psfex is installed properly as psfex. OK
# 2 out of 2 external dependencies installed properly.
#
# You are ready to continue.
# 26

# %%
data=[]
for imageName in all_images:
    os.chdir('/home/aditi/ksp/i-band/data')
    # imageName = '20230525184701-216-RA.wcs.proc.fits'
    # imageName='/home/aakashgpt/Desktop/KSP 5.0/TASK4_photometry/files_TASK_2-20240624T091844Z-001/files_TASK_2/20230525184701-216-RA.wcs.proc.fits'

    with fits.open(imageName) as HDUList:
        header = HDUList[0].header
        image = HDUList[0].data

    zscale = ZScaleInterval().get_limits(image)

    w = WCS(header)
    (raImage, decImage) = w.all_pix2world(image.shape[0]/2, image.shape[1]/2, 1)
    boxsize = 30 # arcminutes
    maxmag = 18

    catNum = 'II/349'
    print(f'\nQuerying Vizier {catNum} around RA {raImage:.4f}, Dec {decImage:.4f} with a radius of {boxsize} arcmin')

    try:
        # You can set the filters for the individual columns (magnitude range, number of detections) inside the Vizier query
        v = Vizier(columns=['*'], column_filters={"gmag":f"<{maxmag}", "Nd":">6", "e_gmag":f"<{1.086/3}"}, row_limit=-1)
        Q = v.query_region(SkyCoord(ra=raImage, dec=decImage, unit=(u.deg, u.deg)), radius=str(boxsize)+'m', catalog=catNum, cache=False)
        # print(Q[0])
    except:
        print('I cannnot reach the Vizier database. Is the internet working?')

    print(Q[0].meta)
    Q[0].meta['desc'] = Q[0].meta.pop('description')
    Q[0].write('/home/aditi/ksp/i-band/data/ps1Catalog.fits', format='fits', overwrite=True)
    ps1_imCoords = w.all_world2pix(Q[0]['RAJ2000'], Q[0]['DEJ2000'], 1)
    good_cat_stars = Q[0][np.where((ps1_imCoords[0] > 500) & (ps1_imCoords[0] < 3500) & (ps1_imCoords[1] > 500) & (ps1_imCoords[1] < 3500))]
    ps1_imCoords = w.all_world2pix(good_cat_stars['RAJ2000'],good_cat_stars['DEJ2000'], 1)


    configFile = 'photomCat.sex'
    catalogName = imageName + '.cat'
    paramName = 'photomCat.param'
    try:
        command = f'source-extractor -c {configFile} {imageName} -CATALOG_NAME {catalogName} -PARAMETERS_NAME {paramName}'
        print(f'Executing command: {command}')
        rval = subprocess.run(command.split(), check=True)
    except subprocess.CalledProcessError as err:
        print(f'Could not run sextractor with exit error {err}')
    with fits.open(catalogName) as HDU:
        # print(HDU.info())
        sourceTable = Table(HDU[2].data)

    # print(sourceTable.colnames)
    # print(sourceTable)

    cleanSources = sourceTable[(sourceTable['FLAGS']==0) & (sourceTable['FWHM_WORLD'] < 2) & (sourceTable['XWIN_IMAGE']<3500) & (sourceTable['XWIN_IMAGE']>500) & (sourceTable['YWIN_IMAGE']<3500) & (sourceTable['YWIN_IMAGE']>500)]
    psfConfigFile = 'psfex_conf.psfex'

    try:
        command = f'psfex -c {psfConfigFile} {catalogName}'
        print(f'Executing command: {command}')
        rval = subprocess.run(command.split(), check=True)
    except subprocess.CalledProcessError as err:
        print(f'Could not run psfex with exit error {err}')
    psfName = imageName + '.psf'
    psfcatalogName = imageName+'.psf.cat'
    psfparamName = 'photomPSF.param' # This is a new set of parameters to be obtained from SExtractor, including PSF-fit magnitudes
    try:
        # We are supplying SExtactor with the PSF model with the PSF_NAME option
        command = f'source-extractor -c {configFile} {imageName} -CATALOG_NAME {psfcatalogName} -PSF_NAME {psfName} -PARAMETERS_NAME {psfparamName}'
        print(f"Executing command: {command}")
        rval = subprocess.run(command.split(), check=True)
    except subprocess.CalledProcessError as err:
        print(f'Could not run sextractor with exit error {err}')
    
    with fits.open(psfcatalogName) as HDU:
        psfsourceTable = Table(HDU[2].data)

    # print(psfsourceTable.colnames)
    # print(psfsourceTable)

    cleanPSFSources = psfsourceTable#[(psfsourceTable['FLAGS']==0)] # & (psfsourceTable['FLAGS_MODEL']==0) ]# & (psfsourceTable['FWHM_WORLD'] < 2) & (psfsourceTable['XMODEL_IMAGE']<3500) & (psfsourceTable['XMODEL_IMAGE']>500) &(psfsourceTable['YMODEL_IMAGE']<3500) &(psfsourceTable['YMODEL_IMAGE']>500)]

    psfsourceCatCoords = SkyCoord(ra=cleanPSFSources['ALPHAWIN_J2000'], dec=cleanPSFSources['DELTAWIN_J2000'], frame='icrs', unit='degree')
    ps1CatCoords = SkyCoord(ra=good_cat_stars['RAJ2000'], dec=good_cat_stars['DEJ2000'], frame='icrs', unit='degree')
    photoDistThresh = 1.2
    idx_psfimage, idx_psfps1, d2d, d3d = ps1CatCoords.search_around_sky(psfsourceCatCoords, photoDistThresh*u.arcsec)

    print(f'Found {len(idx_psfimage)} good cross-matches')

    psfoffsets = ma.array(good_cat_stars['gmag'][idx_psfps1] - cleanPSFSources['MAG_POINTSOURCE'][idx_psfimage])
    zero_psfmean, zero_psfmed, zero_psfstd = sigma_clipped_stats(psfoffsets)
    print('PSF Mean ZP: %.2f\nPSF Median ZP: %.2f\nPSF STD ZP: %.2f'%(zero_psfmean, zero_psfmed, zero_psfstd))
    ra = 210.910674637
    dec = 54.3116510708

    sn2023ixf_coords = SkyCoord(ra=[ra], dec=[dec], frame='icrs', unit='degree')
    idx_sn2023ixf, idx_cleanpsf_sn2023ixf, d2d, d3d = psfsourceCatCoords.search_around_sky(sn2023ixf_coords, photoDistThresh*u.arcsec)
    print(idx_cleanpsf_sn2023ixf)
    # print(f'Found the source at index {idx_cleanpsf_sn2023ixf[0]}')
    sn2023ixf_psfinstmag = cleanPSFSources[idx_cleanpsf_sn2023ixf]['MAG_POINTSOURCE'][1]
    sn2023ixf_psfinstmagerr = cleanPSFSources[idx_cleanpsf_sn2023ixf]['MAGERR_POINTSOURCE'][1]

    sn2023ixf_psfmag = zero_psfmed + sn2023ixf_psfinstmag
    sn2023ixf_psfmagerr = np.sqrt(sn2023ixf_psfinstmagerr**2 + zero_psfstd**2)

    print(f'PSF-fit magnitude of SN2023ixf is {sn2023ixf_psfmag} +/- {sn2023ixf_psfmagerr}')
    data.append([imageName,sn2023ixf_psfmag , sn2023ixf_psfmagerr])
    clear_output(wait=True)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60101.633246 from DATE-OBS'. [astropy.wcs.wcs]
# Querying Vizier II/349 around RA 210.9143, Dec 54.3060 with a radius of 30 arcmin
# {'ID': 'II_349_ps1', 'name': 'II/349/ps1', 'description': 'Pan-STARRS DR1 catalogue, output (on a total of 1,919,106,885 sources)'}
# Executing command: source-extractor -c photomCat.sex 20230606151152-472-RA.wcs.proc.fits -CATALOG_NAME 20230606151152-472-RA.wcs.proc.fits.cat -PARAMETERS_NAME photomCat.param
# >
# ----- Source Extractor 2.25.0 started on 2024-07-24 at 22:02:19 with 1 thread
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing catalog
# > Looking for 20230606151152-472-RA.wcs.proc.fits
# ----- Measuring from: 20230606151152-472-RA.wcs.proc.fits
#       "SN2023ixf" / no ext. header / 4096x4108 / 64 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line: 1024
# > Setting up background map at line: 2048
# > Setting up background map at line: 3072
# > Setting up background map at line: 4096
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: 69.8985    RMS: 14.6051    / Threshold: 146.051
# > Scanning image
# > Line:   25  Objects:        2 detected /        0 sextracted
# > Line:   50  Objects:        3 detected /        0 sextracted
# > Line:   75  Objects:        4 detected /        0 sextracted
# > Line:  100  Objects:        4 detected /        0 sextracted
# > Line:  125  Objects:        5 detected /        0 sextracted
# > Line:  150  Objects:        6 detected /        0 sextracted
# > Line:  175  Objects:        7 detected /        0 sextracted
# > Line:  200  Objects:        9 detected /        0 sextracted
# > Line:  225  Objects:       11 detected /        0 sextracted
# > Line:  250  Objects:       11 detected /        0 sextracted
# > Line:  275  Objects:       12 detected /        0 sextracted
# > Line:  300  Objects:       15 detected /        0 sextracted
# > Line:  325  Objects:       17 detected /        0 sextracted
# > Line:  350  Objects:       17 detected /        0 sextracted
# > Line:  375  Objects:       20 detected /        0 sextracted
# > Line:  400  Objects:       23 detected /        0 sextracted
# > Line:  425  Objects:       29 detected /        0 sextracted
# > Line:  450  Objects:       33 detected /        0 sextracted
# > Line:  475  Objects:       38 detected /        0 sextracted
# > Line:  500  Objects:       39 detected /        0 sextracted
# > Line:  525  Objects:       40 detected /        0 sextracted
# > Line:  550  Objects:       45 detected /        0 sextracted
# > Line:  575  Objects:       46 detected /        0 sextracted
# > Line:  600  Objects:       48 detected /        0 sextracted
# > Line:  625  Objects:       49 detected /        0 sextracted
# > Line:  650  Objects:       51 detected /        0 sextracted
# > Line:  675  Objects:       54 detected /        0 sextracted
# > Line:  700  Objects:       56 detected /        0 sextracted
# > Line:  725  Objects:       58 detected /        0 sextracted
# > Line:  750  Objects:       62 detected /        0 sextracted
# > Line:  775  Objects:       62 detected /        0 sextracted
# > Line:  800  Objects:       65 detected /        0 sextracted
# > Line:  825  Objects:       66 detected /        0 sextracted
# > Line:  850  Objects:       68 detected /        0 sextracted
# > Line:  875  Objects:       70 detected /        0 sextracted
# > Line:  900  Objects:       73 detected /        0 sextracted
# > Line:  925  Objects:       76 detected /        0 sextracted
# > Line:  950  Objects:       80 detected /        0 sextracted
# > Line:  975  Objects:       81 detected /        0 sextracted
# > Line: 1000  Objects:       85 detected /        0 sextracted
# > Line: 1023  Objects:       86 detected /        0 sextracted
# > Line: 1025  Objects:       86 detected /        2 sextracted
# > Line: 1050  Objects:       89 detected /        2 sextracted
# > Line: 1075  Objects:       93 detected /        4 sextracted
# > Line: 1100  Objects:       95 detected /        4 sextracted
# > Line: 1125  Objects:       97 detected /        5 sextracted
# > Line: 1150  Objects:       99 detected /        5 sextracted
# > Line: 1175  Objects:      101 detected /        8 sextracted
# > Line: 1200  Objects:      106 detected /        9 sextracted
# > Line: 1225  Objects:      109 detected /       11 sextracted
# > Line: 1250  Objects:      112 detected /       12 sextracted
# > Line: 1275  Objects:      118 detected /       13 sextracted
# > Line: 1300  Objects:      119 detected /       15 sextracted
# > Line: 1325  Objects:      120 detected /       18 sextracted
# > Line: 1350  Objects:      126 detected /       18 sextracted
# > Line: 1375  Objects:      128 detected /       21 sextracted
# > Line: 1400  Objects:      131 detected /       24 sextracted
# > Line: 1425  Objects:      133 detected /       30 sextracted
# > Line: 1450  Objects:      134 detected /       32 sextracted
# > Line: 1475  Objects:      137 detected /       37 sextracted
# > Line: 1500  Objects:      140 detected /       38 sextracted
# > Line: 1525  Objects:      145 detected /       41 sextracted
# > Line: 1550  Objects:      147 detected /       46 sextracted
# > Line: 1575  Objects:      151 detected /       46 sextracted
# > Line: 1600  Objects:      152 detected /       48 sextracted
# > Line: 1625  Objects:      155 detected /       50 sextracted
# > Line: 1650  Objects:      158 detected /       52 sextracted
# > Line: 1675  Objects:      160 detected /       54 sextracted
# > Line: 1700  Objects:      162 detected /       55 sextracted
# > Line: 1725  Objects:      163 detected /       58 sextracted
# > Line: 1750  Objects:      166 detected /       62 sextracted
# > Line: 1775  Objects:      168 detected /       62 sextracted
# > Line: 1800  Objects:      172 detected /       65 sextracted
# > Line: 1825  Objects:      174 detected /       67 sextracted
# > Line: 1850  Objects:      179 detected /       68 sextracted
# > Line: 1875  Objects:      183 detected /       70 sextracted
# > Line: 1900  Objects:      186 detected /       73 sextracted
# > Line: 1925  Objects:      189 detected /       76 sextracted
# > Line: 1950  Objects:      192 detected /       80 sextracted
# > Line: 3375  Objects:      353 detected /      243 sextracted
# > Line: 3400  Objects:      355 detected /      246 sextracted
# > Line: 3425  Objects:      357 detected /      248 sextracted
# > Line: 3450  Objects:      359 detected /      249 sextracted
# > Line: 3475  Objects:      363 detected /      252 sextracted
# > Line: 3500  Objects:      366 detected /      257 sextracted
# > Line: 3525  Objects:      370 detected /      258 sextracted
# > Line: 3550  Objects:      371 detected /      259 sextracted
# > Line: 3575  Objects:      372 detected /      262 sextracted
# > Line: 3600  Objects:      372 detected /      264 sextracted
# > Line: 3625  Objects:      375 detected /      269 sextracted
# > Line: 3650  Objects:      375 detected /      270 sextracted
# > Line: 3675  Objects:      378 detected /      275 sextracted
# > Line: 3700  Objects:      379 detected /      280 sextracted
# > Line: 3725  Objects:      383 detected /      283 sextracted
# > Line: 3750  Objects:      384 detected /      284 sextracted
# > Line: 3775  Objects:      387 detected /      287 sextracted
# > Line: 3800  Objects:      388 detected /      292 sextracted
# > Line: 3825  Objects:      390 detected /      293 sextracted
# > Line: 3850  Objects:      391 detected /      293 sextracted
# > Line: 3875  Objects:      391 detected /      293 sextracted
# > Line: 3900  Objects:      392 detected /      293 sextracted
# > Line: 3925  Objects:      392 detected /      293 sextracted
# > Line: 3950  Objects:      393 detected /      293 sextracted
# > Line: 3975  Objects:      393 detected /      293 sextracted
# > Line: 4000  Objects:      394 detected /      293 sextracted
# > Line: 4025  Objects:      394 detected /      293 sextracted
# > Line: 4050  Objects:      394 detected /      293 sextracted
# > Line: 4075  Objects:      396 detected /      293 sextracted
# > Line: 4100  Objects:      397 detected /      293 sextracted
#       Objects: detected 397      / sextracted 396
#
# > Closing files
# >
# > All done (in 0.6 s: 7077.8 lines/s , 682.3 detections/s)
#
# > WARNING: NTHREADS != 1 ignored: this build of PSFEx is single-threaded
# Executing command: psfex -c psfex_conf.psfex 20230606151152-472-RA.wcs.proc.fits.cat
# *** PLPLOT WARNING ***
# Driver does not support hardware solid fills, switching to software fill.
#
# >
# ----- Source Extractor 2.25.0 started on 2024-07-24 at 22:02:20 with 1 thread
#
# > Setting catalog parameters
# > Reading PSF information
# > Preparing profile models
# Fitting model: point source
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing catalog
# > Looking for 20230606151152-472-RA.wcs.proc.fits
# ----- Measuring from: 20230606151152-472-RA.wcs.proc.fits
#       "SN2023ixf" / no ext. header / 4096x4108 / 64 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line: 1024
# > Setting up background map at line: 2048
# Executing command: source-extractor -c photomCat.sex 20230606151152-472-RA.wcs.proc.fits -CATALOG_NAME 20230606151152-472-RA.wcs.proc.fits.psf.cat -PSF_NAME 20230606151152-472-RA.wcs.proc.fits.psf -PARAMETERS_NAME photomPSF.param
# > Setting up background map at line: 3072
# > Setting up background map at line: 4096
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: 69.8985    RMS: 14.6051    / Threshold: 146.051
# > Scanning image
# > Line:    1  Objects:        0 detected /        0 sextracted
# > Line:    2  Objects:        0 detected /        0 sextracted
# > Line:    3  Objects:        0 detected /        0 sextracted
# > Line:    4  Objects:        0 detected /        0 sextracted
# > Line:    5  Objects:        1 detected /        0 sextracted
# > Line:    6  Objects:        1 detected /        0 sextracted
# > Line:    7  Objects:        1 detected /        0 sextracted
# > Line:    8  Objects:        1 detected /        0 sextracted
# > Line:    9  Objects:        1 detected /        0 sextracted
# > Line:   10  Objects:        1 detected /        0 sextracted
# > Line:   11  Objects:        1 detected /        0 sextracted
# > Line:   12  Objects:        1 detected /        0 sextracted
# > Line:   13  Objects:        1 detected /        0 sextracted
# > Line:   14  Objects:        1 detected /        0 sextracted
# > Line:   15  Objects:        1 detected /        0 sextracted
# > Line:   16  Objects:        1 detected /        0 sextracted
# > Line:   17  Objects:        2 detected /        0 sextracted
# > Line:   18  Objects:        2 detected /        0 sextracted
# > Line:   19  Objects:        2 detected /        0 sextracted
# > Line:   20  Objects:        2 detected /        0 sextracted
# > Line:   21  Objects:        2 detected /        0 sextracted
# > Line:   22  Objects:        2 detected /        0 sextracted
# > Line:   23  Objects:        2 detected /        0 sextracted
# > Line:   24  Objects:        2 detected /        0 sextracted
# > Line:   25  Objects:        2 detected /        0 sextracted
# > Line:   26  Objects:        2 detected /        0 sextracted
# > Line:   27  Objects:        2 detected /        0 sextracted
# > Line:   28  Objects:        2 detected /        0 sextracted
# > Line:   29  Objects:        2 detected /        0 sextracted
# > Line:   30  Objects:        2 detected /        0 sextracted
# > Line:   31  Objects:        2 detected /        0 sextracted
# > Line:   32  Objects:        2 detected /        0 sextracted
# > Line:   33  Objects:        2 detected /        0 sextracted
# > Line:   34  Objects:        2 detected /        0 sextracted
# > Line:   35  Objects:        2 detected /        0 sextracted
# > Line:   36  Objects:        2 detected /        0 sextracted
# > Line:   37  Objects:        2 detected /        0 sextracted
# > Line:   38  Objects:        2 detected /        0 sextracted
# > Line:   39  Objects:        2 detected /        0 sextracted
# > Line:   40  Objects:        2 detected /        0 sextracted
# > Line:   41  Objects:        2 detected /        0 sextracted
# > Line:   42  Objects:        2 detected /        0 sextracted
# > Line:   43  Objects:        2 detected /        0 sextracted
# > Line:   44  Objects:        2 detected /        0 sextracted
# > Line:   45  Objects:        2 detected /        0 sextracted
# > Line:   46  Objects:        2 detected /        0 sextracted
# > Line:   47  Objects:        2 detected /        0 sextracted
# > Line:   48  Objects:        3 detected /        0 sextracted
# > Line:   49  Objects:        3 detected /        0 sextracted
# > Line:   50  Objects:        3 detected /        0 sextracted
# > Line:   51  Objects:        3 detected /        0 sextracted
# > Line:   52  Objects:        3 detected /        0 sextracted
# > Line:   53  Objects:        3 detected /        0 sextracted
# > Line:   54  Objects:        3 detected /        0 sextracted
# > Line:   55  Objects:        3 detected /        0 sextracted
# > Line:   56  Objects:        3 detected /        0 sextracted
# > Line:   57  Objects:        3 detected /        0 sextracted
# > Line:   58  Objects:        3 detected /        0 sextracted
# > Line:   59  Objects:        4 detected /        0 sextracted
# > Line:   60  Objects:        4 detected /        0 sextracted
# > Line:   61  Objects:        4 detected /        0 sextracted
# > Line:   62  Objects:        4 detected /        0 sextracted
# > Line:   63  Objects:        4 detected /        0 sextracted
# > Line:   64  Objects:        4 detected /        0 sextracted
# > Line:   65  Objects:        4 detected /        0 sextracted
# > Line:   66  Objects:        4 detected /        0 sextracted
# > Line:   67  Objects:        4 detected /        0 sextracted
# > Line:   68  Objects:        4 detected /        0 sextracted
# > Line:   69  Objects:        4 detected /        0 sextracted
# > Line:   70  Objects:        4 detected /        0 sextracted
# > Line:   71  Objects:        4 detected /        0 sextracted
# > Line:   72  Objects:        4 detected /        0 sextracted
# > Line:   73  Objects:        4 detected /        0 sextracted
# > Line:   74  Objects:        4 detected /        0 sextracted
# > Line:   75  Objects:        4 detected /        0 sextracted
# > Line:   76  Objects:        4 detected /        0 sextracted
# > Line:   77  Objects:        4 detected /        0 sextracted
# > Line:   78  Objects:        4 detected /        0 sextracted
# > Line:   79  Objects:        4 detected /        0 sextracted
# > Line:   80  Objects:        4 detected /        0 sextracted
# > Line:   81  Objects:        4 detected /        0 sextracted
# > Line:   82  Objects:        4 detected /        0 sextracted
# > Line:   83  Objects:        4 detected /        0 sextracted
# > Line:   84  Objects:        4 detected /        0 sextracted
# > Line:   85  Objects:        4 detected /        0 sextracted
# > Line:   86  Objects:        4 detected /        0 sextracted
# > Line:   87  Objects:        4 detected /        0 sextracted
# > Line:   88  Objects:        4 detected /        0 sextracted
# > Line:   89  Objects:        4 detected /        0 sextracted
# > Line:   90  Objects:        4 detected /        0 sextracted
# > Line:   91  Objects:        4 detected /        0 sextracted
# > Line:   92  Objects:        4 detected /        0 sextracted
# > Line:   93  Objects:        4 detected /        0 sextracted
# > Line:   94  Objects:        4 detected /        0 sextracted
# > Line:   95  Objects:        4 detected /        0 sextracted
# > Line:   96  Objects:        4 detected /        0 sextracted
# > Line:   97  Objects:        4 detected /        0 sextracted
# > Line:   98  Objects:        4 detected /        0 sextracted
# > Line:   99  Objects:        4 detected /        0 sextracted
# > Line:  100  Objects:        4 detected /        0 sextracted
# > Line:  101  Objects:        4 detected /        0 sextracted
# > Line:  102  Objects:        4 detected /        0 sextracted
# > Line:  103  Objects:        4 detected /        0 sextracted
# > Line:  104  Objects:        4 detected /        0 sextracted
# > Line:  105  Objects:        4 detected /        0 sextracted
# > Line:  106  Objects:        4 detected /        0 sextracted
# > Line:  107  Objects:        4 detected /        0 sextracted
# > Line:  108  Objects:        4 detected /        0 sextracted
# > Line:  109  Objects:        4 detected /        0 sextracted
# > Line:  110  Objects:        4 detected /        0 sextracted
# > Line:  111  Objects:        4 detected /        0 sextracted
# > Line:  112  Objects:        4 detected /        0 sextracted
# > Line:  113  Objects:        4 detected /        0 sextracted
# > Line:  114  Objects:        4 detected /        0 sextracted
# > Line:  115  Objects:        4 detected /        0 sextracted
# > Line:  116  Objects:        4 detected /        0 sextracted
# > Line:  117  Objects:        4 detected /        0 sextracted
# > Line:  118  Objects:        5 detected /        0 sextracted
# > Line:  119  Objects:        5 detected /        0 sextracted
# > Line:  120  Objects:        5 detected /        0 sextracted
# > Line:  121  Objects:        5 detected /        0 sextracted
# > Line:  122  Objects:        5 detected /        0 sextracted
# > Line:  123  Objects:        5 detected /        0 sextracted
# > Line:  124  Objects:        5 detected /        0 sextracted
# > Line:  125  Objects:        5 detected /        0 sextracted
# > Line:  126  Objects:        5 detected /        0 sextracted
# > Line:  127  Objects:        5 detected /        0 sextracted
# > Line:  128  Objects:        5 detected /        0 sextracted
# > Line:  129  Objects:        5 detected /        0 sextracted
# > Line:  130  Objects:        5 detected /        0 sextracted
# > Line:  131  Objects:        5 detected /        0 sextracted
# > Line:  132  Objects:        5 detected /        0 sextracted
# > Line:  133  Objects:        5 detected /        0 sextracted
# > Line:  134  Objects:        5 detected /        0 sextracted
# > Line:  135  Objects:        5 detected /        0 sextracted
# > Line:  136  Objects:        5 detected /        0 sextracted
# > Line:  137  Objects:        5 detected /        0 sextracted
# > Line:  138  Objects:        5 detected /        0 sextracted
# > Line:  139  Objects:        5 detected /        0 sextracted
# > Line:  140  Objects:        5 detected /        0 sextracted
# > Line:  141  Objects:        5 detected /        0 sextracted
# > Line:  142  Objects:        5 detected /        0 sextracted
# > Line:  143  Objects:        5 detected /        0 sextracted
# > Line:  144  Objects:        5 detected /        0 sextracted
# > Line:  145  Objects:        6 detected /        0 sextracted
# > Line:  146  Objects:        6 detected /        0 sextracted
# > Line:  147  Objects:        6 detected /        0 sextracted
# > Line:  148  Objects:        6 detected /        0 sextracted
# > Line:  149  Objects:        6 detected /        0 sextracted
# > Line:  150  Objects:        6 detected /        0 sextracted
# > Line:  151  Objects:        6 detected /        0 sextracted
# > Line:  152  Objects:        6 detected /        0 sextracted
# > Line:  153  Objects:        6 detected /        0 sextracted
# > Line:  154  Objects:        6 detected /        0 sextracted
# > Line:  155  Objects:        6 detected /        0 sextracted
# > Line:  156  Objects:        6 detected /        0 sextracted
# > Line:  157  Objects:        6 detected /        0 sextracted
# > Line:  158  Objects:        6 detected /        0 sextracted
# > Line:  159  Objects:        6 detected /        0 sextracted
# > Line:  160  Objects:        6 detected /        0 sextracted
# > Line:  161  Objects:        6 detected /        0 sextracted
# > Line:  162  Objects:        7 detected /        0 sextracted
# > Line:  163  Objects:        7 detected /        0 sextracted
# > Line:  164  Objects:        7 detected /        0 sextracted
# > Line:  165  Objects:        7 detected /        0 sextracted
# > Line:  166  Objects:        7 detected /        0 sextracted
# > Line:  167  Objects:        7 detected /        0 sextracted
# > Line:  168  Objects:        7 detected /        0 sextracted
# > Line:  169  Objects:        7 detected /        0 sextracted
# > Line:  170  Objects:        7 detected /        0 sextracted
# > Line:  171  Objects:        7 detected /        0 sextracted
# > Line:  172  Objects:        7 detected /        0 sextracted
# > Line:  173  Objects:        7 detected /        0 sextracted
# > Line:  174  Objects:        7 detected /        0 sextracted
# > Line:  175  Objects:        7 detected /        0 sextracted
# > Line:  176  Objects:        7 detected /        0 sextracted
# > Line:  177  Objects:        7 detected /        0 sextracted
# > Line:  178  Objects:        8 detected /        0 sextracted
# > Line:  179  Objects:        8 detected /        0 sextracted
# > Line:  180  Objects:        8 detected /        0 sextracted
# > Line:  181  Objects:        8 detected /        0 sextracted
# > Line:  182  Objects:        8 detected /        0 sextracted
# > Line:  183  Objects:        8 detected /        0 sextracted
# > Line:  184  Objects:        8 detected /        0 sextracted
# > Line:  185  Objects:        8 detected /        0 sextracted
# > Line:  186  Objects:        8 detected /        0 sextracted
# > Line:  187  Objects:        8 detected /        0 sextracted
# > Line:  188  Objects:        8 detected /        0 sextracted
# > Line:  189  Objects:        8 detected /        0 sextracted
# > Line:  190  Objects:        8 detected /        0 sextracted
# > Line:  191  Objects:        8 detected /        0 sextracted
# > Line:  192  Objects:        9 detected /        0 sextracted
# > Line:  193  Objects:        9 detected /        0 sextracted
# > Line:  194  Objects:        9 detected /        0 sextracted
# > Line:  195  Objects:        9 detected /        0 sextracted
# > Line:  196  Objects:        9 detected /        0 sextracted
# > Line:  197  Objects:        9 detected /        0 sextracted
# > Line:  198  Objects:        9 detected /        0 sextracted
# > Line:  199  Objects:        9 detected /        0 sextracted
# > Line:  200  Objects:        9 detected /        0 sextracted
# > Line:  201  Objects:        9 detected /        0 sextracted
# > Line:  202  Objects:        9 detected /        0 sextracted
# > Line:  203  Objects:        9 detected /        0 sextracted
# > Line:  204  Objects:        9 detected /        0 sextracted
# > Line:  205  Objects:        9 detected /        0 sextracted
# > Line:  206  Objects:        9 detected /        0 sextracted
# > Line:  207  Objects:        9 detected /        0 sextracted
# > Line:  208  Objects:        9 detected /        0 sextracted
# > Line:  209  Objects:        9 detected /        0 sextracted
# > Line:  210  Objects:        9 detected /        0 sextracted
# > Line:  211  Objects:        9 detected /        0 sextracted
# > Line:  212  Objects:        9 detected /        0 sextracted
# > Line:  213  Objects:       10 detected /        0 sextracted
# > Line:  214  Objects:       10 detected /        0 sextracted
# > Line:  215  Objects:       10 detected /        0 sextracted
# > Line:  216  Objects:       10 detected /        0 sextracted
# > Line:  217  Objects:       10 detected /        0 sextracted
# > Line:  218  Objects:       11 detected /        0 sextracted
# > Line:  219  Objects:       11 detected /        0 sextracted
# > Line:  220  Objects:       11 detected /        0 sextracted
# > Line:  221  Objects:       11 detected /        0 sextracted
# > Line:  222  Objects:       11 detected /        0 sextracted
# > Line:  223  Objects:       11 detected /        0 sextracted
# > Line:  224  Objects:       11 detected /        0 sextracted
# > Line:  225  Objects:       11 detected /        0 sextracted
# > Line:  226  Objects:       11 detected /        0 sextracted
# > Line:  227  Objects:       11 detected /        0 sextracted
# > Line:  228  Objects:       11 detected /        0 sextracted
# > Line:  229  Objects:       11 detected /        0 sextracted
# > Line:  230  Objects:       11 detected /        0 sextracted
# > Line:  231  Objects:       11 detected /        0 sextracted
# > Line:  232  Objects:       11 detected /        0 sextracted
# > Line:  233  Objects:       11 detected /        0 sextracted
# > Line:  234  Objects:       11 detected /        0 sextracted
# > Line:  235  Objects:       11 detected /        0 sextracted
# > Line:  236  Objects:       11 detected /        0 sextracted
# > Line:  237  Objects:       11 detected /        0 sextracted
# > Line:  238  Objects:       11 detected /        0 sextracted
# > Line:  239  Objects:       11 detected /        0 sextracted
# > Line:  240  Objects:       11 detected /        0 sextracted
# > Line:  241  Objects:       11 detected /        0 sextracted
# > Line:  242  Objects:       11 detected /        0 sextracted
# > Line:  243  Objects:       11 detected /        0 sextracted
# > Line:  244  Objects:       11 detected /        0 sextracted
# > Line:  245  Objects:       11 detected /        0 sextracted
# > Line:  246  Objects:       11 detected /        0 sextracted
# > Line:  247  Objects:       11 detected /        0 sextracted
# > Line:  248  Objects:       11 detected /        0 sextracted
# > Line:  249  Objects:       11 detected /        0 sextracted
# > Line:  250  Objects:       11 detected /        0 sextracted
# > Line:  251  Objects:       11 detected /        0 sextracted
# > Line:  252  Objects:       11 detected /        0 sextracted
# > Line:  253  Objects:       11 detected /        0 sextracted
# > Line:  254  Objects:       11 detected /        0 sextracted
# > Line:  255  Objects:       11 detected /        0 sextracted
# > Line:  256  Objects:       11 detected /        0 sextracted
# > Line:  257  Objects:       11 detected /        0 sextracted
# > Line:  258  Objects:       11 detected /        0 sextracted
# > Line:  259  Objects:       11 detected /        0 sextracted
# > Line:  260  Objects:       11 detected /        0 sextracted
# > Line:  261  Objects:       11 detected /        0 sextracted
# > Line:  262  Objects:       12 detected /        0 sextracted
# > Line:  263  Objects:       12 detected /        0 sextracted
# > Line:  264  Objects:       12 detected /        0 sextracted
# > Line:  265  Objects:       12 detected /        0 sextracted
# > Line:  266  Objects:       12 detected /        0 sextracted
# > Line:  267  Objects:       12 detected /        0 sextracted
# > Line:  268  Objects:       12 detected /        0 sextracted
# > Line:  269  Objects:       12 detected /        0 sextracted
# > Line:  270  Objects:       12 detected /        0 sextracted
# > Line:  271  Objects:       12 detected /        0 sextracted
# > Line:  272  Objects:       12 detected /        0 sextracted
# > Line:  273  Objects:       12 detected /        0 sextracted
# > Line:  274  Objects:       12 detected /        0 sextracted
# > Line:  275  Objects:       12 detected /        0 sextracted
# > Line:  276  Objects:       12 detected /        0 sextracted
# > Line:  277  Objects:       12 detected /        0 sextracted
# > Line:  278  Objects:       12 detected /        0 sextracted
# > Line:  279  Objects:       12 detected /        0 sextracted
# > Line:  280  Objects:       12 detected /        0 sextracted
# > Line:  281  Objects:       12 detected /        0 sextracted
# > Line:  282  Objects:       12 detected /        0 sextracted
# > Line:  283  Objects:       13 detected /        0 sextracted
# > Line:  284  Objects:       14 detected /        0 sextracted
# > Line:  285  Objects:       14 detected /        0 sextracted
# > Line:  286  Objects:       14 detected /        0 sextracted
# > Line:  287  Objects:       14 detected /        0 sextracted
# > Line:  288  Objects:       15 detected /        0 sextracted
# > Line:  289  Objects:       15 detected /        0 sextracted
# > Line:  290  Objects:       15 detected /        0 sextracted
# > Line:  291  Objects:       15 detected /        0 sextracted
# > Line:  292  Objects:       15 detected /        0 sextracted
# > Line:  293  Objects:       15 detected /        0 sextracted
# > Line:  294  Objects:       15 detected /        0 sextracted
# > Line:  295  Objects:       15 detected /        0 sextracted
# > Line:  296  Objects:       15 detected /        0 sextracted
# > Line:  297  Objects:       15 detected /        0 sextracted
# > Line:  298  Objects:       15 detected /        0 sextracted
# > Line:  299  Objects:       15 detected /        0 sextracted
# > Line:  300  Objects:       15 detected /        0 sextracted
# > Line:  301  Objects:       15 detected /        0 sextracted
# > Line:  302  Objects:       15 detected /        0 sextracted
# > Line:  303  Objects:       15 detected /        0 sextracted
# > Line:  304  Objects:       15 detected /        0 sextracted
# > Line:  305  Objects:       15 detected /        0 sextracted
# > Line:  306  Objects:       16 detected /        0 sextracted
# > Line:  307  Objects:       16 detected /        0 sextracted
# > Line:  308  Objects:       17 detected /        0 sextracted
# > Line:  309  Objects:       17 detected /        0 sextracted
# > Line:  310  Objects:       17 detected /        0 sextracted
# > Line:  311  Objects:       17 detected /        0 sextracted
# > Line:  312  Objects:       17 detected /        0 sextracted
# > Line:  313  Objects:       17 detected /        0 sextracted
# > Line:  314  Objects:       17 detected /        0 sextracted
# > Line:  315  Objects:       17 detected /        0 sextracted
# > Line:  316  Objects:       17 detected /        0 sextracted
# > Line:  317  Objects:       17 detected /        0 sextracted
# > Line:  318  Objects:       17 detected /        0 sextracted
# > Line:  319  Objects:       17 detected /        0 sextracted
# > Line:  320  Objects:       17 detected /        0 sextracted
# > Line:  321  Objects:       17 detected /        0 sextracted
# > Line:  322  Objects:       17 detected /        0 sextracted
# > Line:  323  Objects:       17 detected /        0 sextracted
# > Line:  324  Objects:       17 detected /        0 sextracted
# > Line:  325  Objects:       17 detected /        0 sextracted
# > Line:  326  Objects:       17 detected /        0 sextracted
# > Line:  327  Objects:       17 detected /        0 sextracted
# > Line:  328  Objects:       17 detected /        0 sextracted
# > Line:  329  Objects:       17 detected /        0 sextracted
# > Line:  330  Objects:       17 detected /        0 sextracted
# > Line:  331  Objects:       17 detected /        0 sextracted
# > Line:  332  Objects:       17 detected /        0 sextracted
# > Line:  333  Objects:       17 detected /        0 sextracted
# > Line:  334  Objects:       17 detected /        0 sextracted
# > Line:  335  Objects:       17 detected /        0 sextracted
# > Line:  336  Objects:       17 detected /        0 sextracted
# > Line:  337  Objects:       17 detected /        0 sextracted
# > Line:  338  Objects:       17 detected /        0 sextracted
# > Line:  339  Objects:       17 detected /        0 sextracted
# > Line:  340  Objects:       17 detected /        0 sextracted
# > Line:  341  Objects:       17 detected /        0 sextracted
# > Line:  342  Objects:       17 detected /        0 sextracted
# > Line:  343  Objects:       17 detected /        0 sextracted
# > Line:  344  Objects:       17 detected /        0 sextracted
# > Line:  345  Objects:       17 detected /        0 sextracted
# > Line:  346  Objects:       17 detected /        0 sextracted
# > Line:  347  Objects:       17 detected /        0 sextracted
# > Line:  348  Objects:       17 detected /        0 sextracted
# > Line:  349  Objects:       17 detected /        0 sextracted
# > Line:  350  Objects:       17 detected /        0 sextracted
# > Line:  351  Objects:       17 detected /        0 sextracted
# > Line:  352  Objects:       17 detected /        0 sextracted
# > Line:  353  Objects:       17 detected /        0 sextracted
# > Line:  354  Objects:       17 detected /        0 sextracted
# > Line:  355  Objects:       18 detected /        0 sextracted
# > Line:  356  Objects:       18 detected /        0 sextracted
# > Line:  357  Objects:       18 detected /        0 sextracted
# > Line:  358  Objects:       18 detected /        0 sextracted
# > Line:  359  Objects:       18 detected /        0 sextracted
# > Line:  360  Objects:       18 detected /        0 sextracted
# > Line:  361  Objects:       18 detected /        0 sextracted
# > Line:  362  Objects:       18 detected /        0 sextracted
# > Line:  363  Objects:       19 detected /        0 sextracted
# > Line:  364  Objects:       19 detected /        0 sextracted
# > Line:  365  Objects:       19 detected /        0 sextracted
# > Line:  366  Objects:       19 detected /        0 sextracted
# > Line:  367  Objects:       19 detected /        0 sextracted
# > Line:  368  Objects:       19 detected /        0 sextracted
# > Line:  369  Objects:       19 detected /        0 sextracted
# > Line:  370  Objects:       19 detected /        0 sextracted
# > Line:  371  Objects:       20 detected /        0 sextracted
# > Line:  372  Objects:       20 detected /        0 sextracted
# > Line:  373  Objects:       20 detected /        0 sextracted
# > Line:  374  Objects:       20 detected /        0 sextracted
# > Line:  375  Objects:       20 detected /        0 sextracted
# > Line:  376  Objects:       21 detected /        0 sextracted
# > Line:  377  Objects:       21 detected /        0 sextracted
# > Line:  378  Objects:       21 detected /        0 sextracted
# > Line:  379  Objects:       21 detected /        0 sextracted
# > Line:  380  Objects:       21 detected /        0 sextracted
# > Line:  381  Objects:       22 detected /        0 sextracted
# > Line:  382  Objects:       22 detected /        0 sextracted
# > Line:  383  Objects:       22 detected /        0 sextracted
# > Line:  384  Objects:       23 detected /        0 sextracted
# > Line:  385  Objects:       23 detected /        0 sextracted
# > Line:  386  Objects:       23 detected /        0 sextracted
# > Line:  387  Objects:       23 detected /        0 sextracted
# > Line:  388  Objects:       23 detected /        0 sextracted
# > Line:  389  Objects:       23 detected /        0 sextracted
# > Line:  390  Objects:       23 detected /        0 sextracted
# > Line:  391  Objects:       23 detected /        0 sextracted
# > Line:  392  Objects:       23 detected /        0 sextracted
# > Line:  393  Objects:       23 detected /        0 sextracted
# > Line:  394  Objects:       23 detected /        0 sextracted
# > Line:  395  Objects:       23 detected /        0 sextracted
# > Line:  396  Objects:       23 detected /        0 sextracted
# > Line:  397  Objects:       23 detected /        0 sextracted
# > Line:  398  Objects:       23 detected /        0 sextracted
# > Line:  399  Objects:       23 detected /        0 sextracted
# > Line:  400  Objects:       23 detected /        0 sextracted
# > Line:  401  Objects:       24 detected /        0 sextracted
# > Line:  402  Objects:       24 detected /        0 sextracted
# > Line:  403  Objects:       25 detected /        0 sextracted
# > Line:  404  Objects:       25 detected /        0 sextracted
# > Line:  405  Objects:       25 detected /        0 sextracted
# > Line:  406  Objects:       25 detected /        0 sextracted
# > Line:  407  Objects:       25 detected /        0 sextracted
# > Line:  408  Objects:       26 detected /        0 sextracted
# > Line:  409  Objects:       27 detected /        0 sextracted
# > Line:  410  Objects:       28 detected /        0 sextracted
# > Line:  411  Objects:       28 detected /        0 sextracted
# > Line:  412  Objects:       28 detected /        0 sextracted
# > Line:  413  Objects:       28 detected /        0 sextracted
# > Line:  414  Objects:       28 detected /        0 sextracted
# > Line:  415  Objects:       28 detected /        0 sextracted
# > Line:  416  Objects:       28 detected /        0 sextracted
# > Line:  417  Objects:       28 detected /        0 sextracted
# > Line:  418  Objects:       28 detected /        0 sextracted
# > Line:  419  Objects:       28 detected /        0 sextracted
# > Line:  420  Objects:       29 detected /        0 sextracted
# > Line:  421  Objects:       29 detected /        0 sextracted
# > Line:  422  Objects:       29 detected /        0 sextracted
# > Line:  423  Objects:       29 detected /        0 sextracted
# > Line:  424  Objects:       29 detected /        0 sextracted
# > Line:  425  Objects:       29 detected /        0 sextracted
# > Line:  426  Objects:       29 detected /        0 sextracted
# > Line:  427  Objects:       29 detected /        0 sextracted
# > Line:  428  Objects:       29 detected /        0 sextracted
# > Line:  429  Objects:       29 detected /        0 sextracted
# > Line:  430  Objects:       29 detected /        0 sextracted
# > Line:  431  Objects:       29 detected /        0 sextracted
# > Line:  432  Objects:       29 detected /        0 sextracted
# > Line:  433  Objects:       30 detected /        0 sextracted
# > Line:  434  Objects:       30 detected /        0 sextracted
# > Line:  435  Objects:       30 detected /        0 sextracted
# > Line:  436  Objects:       30 detected /        0 sextracted
# > Line:  437  Objects:       30 detected /        0 sextracted
# > Line:  438  Objects:       30 detected /        0 sextracted
# > Line:  439  Objects:       30 detected /        0 sextracted
# > Line:  440  Objects:       30 detected /        0 sextracted
# > Line:  441  Objects:       30 detected /        0 sextracted
# > Line:  442  Objects:       30 detected /        0 sextracted
# > Line:  443  Objects:       30 detected /        0 sextracted
# > Line:  444  Objects:       31 detected /        0 sextracted
# > Line:  445  Objects:       31 detected /        0 sextracted
# > Line:  446  Objects:       33 detected /        0 sextracted
# > Line:  447  Objects:       33 detected /        0 sextracted
# > Line:  448  Objects:       33 detected /        0 sextracted
# > Line:  449  Objects:       33 detected /        0 sextracted
# > Line:  450  Objects:       33 detected /        0 sextracted
# > Line:  451  Objects:       33 detected /        0 sextracted
# > Line:  452  Objects:       33 detected /        0 sextracted
# > Line:  453  Objects:       33 detected /        0 sextracted
# > Line:  454  Objects:       33 detected /        0 sextracted
# > Line:  455  Objects:       33 detected /        0 sextracted
# > Line:  456  Objects:       33 detected /        0 sextracted
# > Line:  457  Objects:       33 detected /        0 sextracted
# > Line:  458  Objects:       33 detected /        0 sextracted
# > Line:  459  Objects:       33 detected /        0 sextracted
# > Line:  460  Objects:       34 detected /        0 sextracted
# > Line:  461  Objects:       34 detected /        0 sextracted
# > Line:  462  Objects:       34 detected /        0 sextracted
# > Line:  463  Objects:       35 detected /        0 sextracted
# > Line:  464  Objects:       35 detected /        0 sextracted
# > Line:  465  Objects:       36 detected /        0 sextracted
# > Line:  466  Objects:       36 detected /        0 sextracted
# > Line:  467  Objects:       36 detected /        0 sextracted
# > Line:  468  Objects:       36 detected /        0 sextracted
# > Line:  469  Objects:       36 detected /        0 sextracted
# > Line:  470  Objects:       36 detected /        0 sextracted
# > Line:  471  Objects:       36 detected /        0 sextracted
# > Line:  472  Objects:       37 detected /        0 sextracted
# > Line:  473  Objects:       37 detected /        0 sextracted
# > Line:  474  Objects:       38 detected /        0 sextracted
# > Line:  475  Objects:       38 detected /        0 sextracted
# > Line:  476  Objects:       38 detected /        0 sextracted
# > Line:  477  Objects:       38 detected /        0 sextracted
# > Line:  478  Objects:       38 detected /        0 sextracted
# > Line:  479  Objects:       38 detected /        0 sextracted
# > Line:  480  Objects:       38 detected /        0 sextracted
# > Line:  481  Objects:       38 detected /        0 sextracted
# > Line:  482  Objects:       38 detected /        0 sextracted
# > Line:  483  Objects:       38 detected /        0 sextracted
# > Line:  484  Objects:       38 detected /        0 sextracted
# > Line:  485  Objects:       38 detected /        0 sextracted
# > Line:  486  Objects:       38 detected /        0 sextracted
# > Line:  487  Objects:       38 detected /        0 sextracted
# > Line:  488  Objects:       38 detected /        0 sextracted
# > Line:  489  Objects:       38 detected /        0 sextracted
# > Line:  490  Objects:       38 detected /        0 sextracted
# > Line:  491  Objects:       38 detected /        0 sextracted
# > Line:  492  Objects:       38 detected /        0 sextracted
# > Line:  493  Objects:       38 detected /        0 sextracted
# > Line:  494  Objects:       38 detected /        0 sextracted
# > Line:  495  Objects:       38 detected /        0 sextracted
# > Line:  496  Objects:       38 detected /        0 sextracted
# > Line:  497  Objects:       38 detected /        0 sextracted
# > Line:  498  Objects:       38 detected /        0 sextracted
# > Line:  499  Objects:       38 detected /        0 sextracted
# > Line:  500  Objects:       39 detected /        0 sextracted
# > Line:  501  Objects:       39 detected /        0 sextracted
# > Line:  502  Objects:       39 detected /        0 sextracted
# > Line:  503  Objects:       39 detected /        0 sextracted
# > Line:  504  Objects:       39 detected /        0 sextracted
# > Line:  505  Objects:       39 detected /        0 sextracted
# > Line:  506  Objects:       39 detected /        0 sextracted
# > Line:  507  Objects:       39 detected /        0 sextracted
# > Line:  508  Objects:       39 detected /        0 sextracted
# > Line:  509  Objects:       39 detected /        0 sextracted
# > Line:  510  Objects:       39 detected /        0 sextracted
# > Line:  511  Objects:       39 detected /        0 sextracted
# > Line:  512  Objects:       39 detected /        0 sextracted
# > Line:  513  Objects:       39 detected /        0 sextracted
# > Line:  514  Objects:       39 detected /        0 sextracted
# > Line:  515  Objects:       40 detected /        0 sextracted
# > Line:  516  Objects:       40 detected /        0 sextracted
# > Line:  517  Objects:       40 detected /        0 sextracted
# > Line:  518  Objects:       40 detected /        0 sextracted
# > Line:  519  Objects:       40 detected /        0 sextracted
# > Line:  520  Objects:       40 detected /        0 sextracted
# > Line:  521  Objects:       40 detected /        0 sextracted
# > Line:  522  Objects:       40 detected /        0 sextracted
# > Line:  523  Objects:       40 detected /        0 sextracted
# > Line:  524  Objects:       40 detected /        0 sextracted
# > Line:  525  Objects:       40 detected /        0 sextracted
# > Line:  526  Objects:       40 detected /        0 sextracted
# > Line:  527  Objects:       40 detected /        0 sextracted
# > Line:  528  Objects:       40 detected /        0 sextracted
# > Line:  529  Objects:       40 detected /        0 sextracted
# > Line:  530  Objects:       41 detected /        0 sextracted
# > Line:  531  Objects:       41 detected /        0 sextracted
# > Line:  532  Objects:       41 detected /        0 sextracted
# > Line:  533  Objects:       41 detected /        0 sextracted
# > Line:  534  Objects:       41 detected /        0 sextracted
# > Line:  535  Objects:       41 detected /        0 sextracted
# > Line:  536  Objects:       42 detected /        0 sextracted
# > Line:  537  Objects:       42 detected /        0 sextracted
# > Line:  538  Objects:       44 detected /        0 sextracted
# > Line:  539  Objects:       44 detected /        0 sextracted
# > Line:  540  Objects:       44 detected /        0 sextracted
# > Line:  541  Objects:       44 detected /        0 sextracted
# > Line:  542  Objects:       45 detected /        0 sextracted
# > Line:  543  Objects:       45 detected /        0 sextracted
# > Line:  544  Objects:       45 detected /        0 sextracted
# > Line:  545  Objects:       45 detected /        0 sextracted
# > Line:  546  Objects:       45 detected /        0 sextracted
# > Line:  547  Objects:       45 detected /        0 sextracted
# > Line:  548  Objects:       45 detected /        0 sextracted
# > Line:  549  Objects:       45 detected /        0 sextracted
# > Line:  550  Objects:       45 detected /        0 sextracted
# > Line:  551  Objects:       45 detected /        0 sextracted
# > Line:  552  Objects:       45 detected /        0 sextracted
# ...
# > Line: 2168  Objects:      228 detected /      100 sextracted
# > Line: 2169  Objects:      228 detected /      100 sextracted
# > Line: 2170  Objects:      228 detected /      100 sextracted
# > Line: 2171  Objects:      228 detected /      100 sextracted
# > Line: 2175  Objects:      228 detected /      101 sextracted
# > Line: 2200  Objects:      229 detected /      106 sextracted
# > Line: 2225  Objects:      231 detected /      109 sextracted
# > Line: 2232  Objects:      232 detected /      110 sextracted
# > Line: 2233  Objects:      232 detected /      110 sextracted
# > Line: 2234  Objects:      232 detected /      110 sextracted
# > Line: 2235  Objects:      232 detected /      110 sextracted
# > Line: 2236  Objects:      232 detected /      110 sextracted
# > Line: 2237  Objects:      232 detected /      110 sextracted
# > Line: 2238  Objects:      232 detected /      110 sextracted
# > Line: 2239  Objects:      232 detected /      110 sextracted
# > Line: 2250  Objects:      234 detected /      112 sextracted
# > Line: 2275  Objects:      236 detected /      118 sextracted
# > Line: 2300  Objects:      237 detected /      119 sextracted
# > Line: 2316  Objects:      237 detected /      120 sextracted
# > Line: 2317  Objects:      237 detected /      120 sextracted
# > Line: 2318  Objects:      237 detected /      120 sextracted
# > Line: 2319  Objects:      237 detected /      120 sextracted
# > Line: 2320  Objects:      237 detected /      120 sextracted
# > Line: 2321  Objects:      237 detected /      120 sextracted
# > Line: 2322  Objects:      237 detected /      120 sextracted
# > Line: 2323  Objects:      237 detected /      120 sextracted
# > Line: 2324  Objects:      237 detected /      120 sextracted
# > Line: 2325  Objects:      237 detected /      120 sextracted
# > Line: 2326  Objects:      237 detected /      120 sextracted
# > Line: 2327  Objects:      237 detected /      120 sextracted
# > Line: 2328  Objects:      237 detected /      120 sextracted
# > Line: 2329  Objects:      237 detected /      120 sextracted
# > Line: 2330  Objects:      237 detected /      120 sextracted
# > Line: 2331  Objects:      237 detected /      120 sextracted
# > Line: 3800  Objects:      388 detected /      292 sextracted
# > Line: 3825  Objects:      390 detected /      293 sextracted
# > Line: 3850  Objects:      391 detected /      293 sextracted
# > Line: 3875  Objects:      391 detected /      293 sextracted
# > Line: 3900  Objects:      392 detected /      293 sextracted
# > Line: 3925  Objects:      392 detected /      293 sextracted
# > Line: 3950  Objects:      393 detected /      293 sextracted
# > Line: 3975  Objects:      393 detected /      293 sextracted
# > Line: 4000  Objects:      394 detected /      293 sextracted
# > Line: 4025  Objects:      394 detected /      293 sextracted
# > Line: 4050  Objects:      394 detected /      293 sextracted
# > Line: 4075  Objects:      396 detected /      293 sextracted
# > Line: 4100  Objects:      397 detected /      293 sextracted
# > Line: 4108  Objects:      397 detected /      300 sextracted
# > Line: 4108  Objects:      397 detected /      310 sextracted
# > Line: 4108  Objects:      397 detected /      320 sextracted
# > Line: 4108  Objects:      397 detected /      330 sextracted
# > Line: 4108  Objects:      397 detected /      340 sextracted
# > Line: 4108  Objects:      397 detected /      350 sextracted
# > Line: 4108  Objects:      397 detected /      360 sextracted
# > Line: 4108  Objects:      397 detected /      370 sextracted
# Found 88 good cross-matches
# PSF Mean ZP: 26.35
# PSF Median ZP: 26.22
# PSF STD ZP: 0.54
# []
# > Line: 4108  Objects:      397 detected /      380 sextracted
# > Line: 4108  Objects:      397 detected /      390 sextracted
#       Objects: detected 397      / sextracted 396
#
# > Closing files
# >
# > All done (in 3.4 s: 1225.4 lines/s , 118.1 detections/s)
# /home/aditi/ksp/astro/lib/python3.10/site-packages/numpy/core/fromnumeric.py:771: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/aditi/ksp/astro/lib/python3.10/site-packages/numpy/core/fromnumeric.py:771: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/aditi/ksp/astro/lib/python3.10/site-packages/numpy/core/fromnumeric.py:771: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 98
#      96 print(idx_cleanpsf_sn2023ixf)
#      97 # print(f'Found the source at index {idx_cleanpsf_sn2023ixf[0]}')
# ---> 98 sn2023ixf_psfinstmag = cleanPSFSources[idx_cleanpsf_sn2023ixf]['MAG_POINTSOURCE'][1]
#      99 sn2023ixf_psfinstmagerr = cleanPSFSources[idx_cleanpsf_sn2023ixf]['MAGERR_POINTSOURCE'][1]
#     101 sn2023ixf_psfmag = zero_psfmed + sn2023ixf_psfinstmag
#
# File astropy/table/_column_mixins.pyx:81, in astropy.table._column_mixins._ColumnGetitemShim.__getitem__()
#
# File astropy/table/_column_mixins.pyx:64, in astropy.table._column_mixins.base_getitem()
#
# File astropy/table/_column_mixins.pyx:76, in astropy.table._column_mixins.column_getitem()
#
# IndexError: index 1 is out of bounds for axis 0 with size 0

# %%
for i in range(len(data)):
    print('image: ',data[i][0],' Magnitude: ',data[i][1],'+/-',data[i][2])

# %%
import matplotlib.pyplot as plt
import datetime

# Extract dates, magnitudes, and errors
dates = [datetime.datetime.strptime(entry[0][:8], '%Y%m%d') for entry in data]
magnitudes = [entry[1] for entry in data]
errors = [entry[2] for entry in data]

# Create the plot
plt.figure(figsize=(10, 5))
plt.errorbar(dates, magnitudes, yerr=errors, fmt='o', capsize=5, label='Magnitude')

# Formatting the plot
plt.xlabel('Date')
plt.ylabel('Magnitude')
plt.title('Magnitude vs Date with Error Bars')
plt.gca().invert_yaxis()  # Magnitude typically decreases upwards
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()
